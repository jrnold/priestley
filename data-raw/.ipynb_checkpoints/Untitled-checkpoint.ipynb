# %%
import yaml
import re
from SPARQLWrapper import SPARQLWrapper, JSON

with open("names_from_description_of_the_chart.txt", "r") as f:
    lines = f.readlines()

# %%
import requests

class Spotlight:
    URL = "https://www.dbpedia-spotlight.org/api"
    
    def __init__(self):
        pass
    
    def spot(self, **kwargs):
        r.get(self.url + '/spot', params = kwargs)
