# %%
import json
import sys
import os.path
import os

# %%
with open("priestley_bios.json", "r") as f:
    bios = json.load(f)

# %%
os.environ
# Out:
# environ({'TERM_SESSION_ID': 'w0t0p0:D73DE04A-B91A-421F-9DF4-4E9E974E84B1', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.88Yhq2bJqw/Listeners', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.K0eOSPf2HG/Render', 'COLORFGBG': '15;0', 'ITERM_PROFILE': 'Default', 'XPC_FLAGS': '0x0', 'LANG': 'en_US.UTF-8', 'PWD': '/Users/jrnold/Documents/projects/priestly/data-raw', 'SHELL': '/bin/zsh', 'TERM_PROGRAM_VERSION': '3.1.6beta5', 'TERM_PROGRAM': 'iTerm.app', 'PATH': '/Users/jrnold/anaconda3/bin:/usr/local/opt/gnu-getopt/bin:/usr/local/opt/llvm/bin:/usr/local/opt/curl/bin:/usr/local/opt/qt/bin:/Users/jrnold/anaconda3/bin:/usr/local/opt/llvm/bin:/usr/local/opt/libxml2/bin:/usr/local/opt/openssl@1.1/bin:/usr/local/opt/icu4c/bin:/usr/local/opt/icu4c/sbin:/usr/local/opt/sqlite/bin:/usr/local/opt/libpq/bin:/usr/local/opt/coreutils/libexec/gnubin:/Users/jrnold/bin:/Users/jrnold/anaconda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/opt/X11/bin', 'DISPLAY': '/p
# ...

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gcp-credentials.json"

# %%
text = "Xenophon was a historian who died in 359 BCE, aged about 90."

# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
entities = client.analyze_entities(document=document).entities

print('Text: {}'.format(text))
# Out:
# Text: Xenophon was a historian who died in 359 BCE, aged about 90.

# %%
people = [entity for entity in entities if entity.type == enums.Entity.Type.PERSON]
if people:
    person = people[0]

# %%
person.metadata.get("wikipedia_url", None)
# Out:
# 'https://en.wikipedia.org/wiki/Xenophon'

# %%
bios
# Out:
# [{'flourished': {'value': 622, 'century': False},
#   'name': 'Aaron',
#   'occupation': 'Ph',
#   'division': 'Mathematicians and Physicians',
#   'text': 'Aaron fl. 622 Ph',
#   'in_1778': True,
#   'in_1764': True,
#   'in_names_omitted': False,
#   'url': None,
#   'lifetype': ['flourished'],
#   'born_max': 602,
#   'born_min': 572,
#   'died_min': 632,
#   'died_max': 652},
#  {'flourished': {'value': -1069, 'century': False},
#   'name': 'Abas',
#   'division': 'Statesmen and Warriors',
#   'text': 'Abas fl. 1070 BC',
#   'in_1778': True,
#   'in_1764': True,
#   'in_names_omitted': False,
#   'url': None,
#   'lifetype': ['flourished'],
#   'born_max': -1089,
#   'born_min': -1119,
#   'died_min': -1059,
#   'died_max': -1039},
#  {'died': {'value': 1628, 'century': False},
#   'age': 70,
#   'name': 'Abbas Shah',
#   'division': 'Statesmen and Warriors',
#   'text': 'Abbas Shah d. 1628. 70',
#   'in_1778': True,
#   'in_1764': True,
#   'in_names_omitted': False,
# ...
